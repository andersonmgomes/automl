# %%
from autoML import AutoML
import ds_utils
automl = AutoML(ds_utils.getDSPriceHousing_ClassProb(), 'high_price')
automl.getResults()
# Out:
# Original dataset dimensions: (5000, 7)
# Dataset dimensions after drop NaN values: (5000, 7)
# ML problem type: Classification
#    Applied metrics: ['f1', 'accuracy', 'roc_auc']
# Normalizing the variables...
# Splitting dataset...
#    X_train dimensions: (4000, 5)
# Features engineering - Testing correlation with Y...
#    Features engineering - Features reduction after correlation test with Y: 0.00% (5 remained)
# Features engineering - Testing redudance between features...
#    Features engineering - Features reduction after redudance test: 20.00% (4 remained)
# Selected algorithms: ['KNeighborsClassifier', 'SVC', 'SVC', 'GaussianProcessClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'MLPClassifier', 'AdaBoostClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'XGBClassifier', 'LogisticRegression']
# Nº of training possible combinations: 360.0 (30.0 features combinations, 12 algorithms)
# ...

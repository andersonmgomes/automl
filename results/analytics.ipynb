# %%
#analysing the results
DS_NAME = 'IRIS'

import os
root_path = os.path.abspath('') #current directory
print('Listing the result files list...')
results_file_list = [f for f in os.listdir(root_path) if ((f[-4:] == '.csv') and (f.find(DS_NAME)>-1))]
results_file_list
# Out:
# Listing the result files list...
# ['20211205_103729_IRIS.csv',
#  '20211205_104915_IRIS.csv',
#  '20211205_105918_IRIS.csv',
#  '20211205_111315_IRIS.csv',
#  '20211205_152759_IRIS_V-SEEDING-POP.csv',
#  '20211205_153821_IRIS_V-SEEDING-POP.csv',
#  '20211205_154931_IRIS_V-SEEDING-POP.csv',
#  '20211205_155901_IRIS_V-SEEDING-POP.csv',
#  '20211205_160528_IRIS_V-SEEDING-POP.csv',
#  '20211205_162543_IRIS_V-SEEDING-POP.csv',
#  '20211205_163219_IRIS_NGEN100.csv',
#  '20211205_164626_IRIS.csv',
#  '20211205_165657_IRIS_CROSSOVER8.csv',
#  '20211205_170441_IRIS_MUT3.csv']

# %%
#loading the dataframe list
import pandas as pd
result_list = [(file_name, pd.read_csv(file_name)) for file_name in results_file_list]
print(len(result_list), 'resuts loaded.')
# Out:
# 14 resuts loaded.

# %%
import numpy as np
main_metric_list = []
for result in result_list:
    main_metric_list.append(result[1].iloc[0,6])
print('média:', np.mean(main_metric_list))
print('max:', np.max(main_metric_list))
# Out:
# média: 0.9550646290922814
# max: 0.9666165413533834

# %%
i = -1 #newest
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_170441_IRIS_MUT3.csv
#     train_order                                          algorithm  \
# 0            11                    QuadraticDiscriminantAnalysis()
# 1             8                    QuadraticDiscriminantAnalysis()
# 2            12                KNeighborsClassifier(n_neighbors=3)
# 3             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 4             3                DecisionTreeClassifier(max_depth=5)
# 5             0                KNeighborsClassifier(n_neighbors=3)
# 6             1                              SVC(probability=True)
# 7            13                              SVC(probability=True)
# 8             4  RandomForestClassifier(max_depth=5, max_featur...
# 9             5              MLPClassifier(alpha=1, max_iter=1000)
# 10            7                                       GaussianNB()
# 11           14                               LogisticRegression()
# 12           10                               LogisticRegression()
# 13            6                               AdaBoostClassifier()
# 14            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0                  ('petal_length', 'sepal_length')           2   15.244949
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3   15.972266
# 2                  ('petal_length', 'sepal_length')           2   15.113519
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3   28.578943
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   15.376448
# 5   ('petal_length', 'sepal_width', 'sepal_length')           3   15.733475
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3   15.621996
# 7                  ('petal_length', 'sepal_length')           2   15.589156
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3    8.249486
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   14.296857
# 10  ('petal_length', 'sepal_width', 'sepal_length')           3   15.009083
# 11                 ('petal_length', 'sepal_length')           2   15.519860
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3   15.414727
# 13  ('petal_length', 'sepal_width', 'sepal_length')           3    8.876419
# 14  ('petal_length', 'sepal_width', 'sepal_length')           3    8.966707
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1396.269531     0.959933  0.960000              0.992667
# 1   1386.765625     0.946600  0.946667              0.990000
# 2   1396.566406     0.946533  0.946667              0.976667
# 3   1385.617188     0.939782  0.940000              0.983000
# 4   1385.656250     0.926516  0.926667              0.944333
# 5   1380.070312     0.919866  0.920000              0.973000
# 6   1380.070312     0.912509  0.913333              0.986000
# 7   1396.039062     0.912509  0.913333              0.987000
# 8   1385.703125     0.912129  0.906667              0.979500
# 9   1386.324219     0.905786  0.893333              0.981667
# 10  1386.175781     0.863560  0.866667              0.975333
# 11  1396.410156     0.842258  0.846667              0.958667
# 12  1396.089844     0.837832  0.840000              0.953000
# 13  1386.312500     0.687696  0.740000              0.973333
# 14  1396.417969          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 1   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 2   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 3   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 4   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 6   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 8   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 9   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 10  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 11  [[10  0  0]\n [ 2  6  2]\n [ 0  0 10]]
# 12  [[10  0  0]\n [ 0  8  2]\n [ 0  1  9]]
# 13  [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 14  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]

# %%
i = -2
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_165657_IRIS_CROSSOVER8.csv
#     train_order                                          algorithm  \
# 0            12  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 1             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 2             8                    QuadraticDiscriminantAnalysis()
# 3             1                              SVC(probability=True)
# 4             0                KNeighborsClassifier(n_neighbors=3)
# 5             5              MLPClassifier(alpha=1, max_iter=1000)
# 6             4  RandomForestClassifier(max_depth=5, max_featur...
# 7             3                DecisionTreeClassifier(max_depth=5)
# 8             7                                       GaussianNB()
# 9            10                               LogisticRegression()
# 10           11                              SVC(probability=True)
# 11            6                               AdaBoostClassifier()
# 12            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0                  ('petal_length', 'sepal_length')           2   28.594280
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3   27.240263
# 2   ('petal_length', 'sepal_width', 'sepal_length')           3   15.311027
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3    9.045565
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   15.917747
# 5   ('petal_length', 'sepal_width', 'sepal_length')           3   14.043293
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3    7.942108
# 7   ('petal_length', 'sepal_width', 'sepal_length')           3   15.388053
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3   15.257276
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   15.467286
# 10                  ('sepal_width', 'sepal_length')           2   15.645517
# 11  ('petal_length', 'sepal_width', 'sepal_length')           3    8.854295
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3    8.980119
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1396.207031     0.953216  0.953333              0.986000
# 1   1385.625000     0.939850  0.940000              0.987667
# 2   1386.644531     0.939748  0.940000              0.993333
# 3   1379.734375     0.933233  0.933333              0.989333
# 4   1379.621094     0.933065  0.933333              0.972667
# 5   1386.246094     0.919799  0.920000              0.978333
# 6   1386.015625     0.913116  0.913333              0.971333
# 7   1385.968750     0.906095  0.913333              0.938667
# 8   1386.539062     0.879193  0.880000              0.972667
# 9   1395.171875     0.844236  0.846667              0.953667
# 10  1395.476562     0.806051  0.806667              0.909667
# 11  1386.195312     0.740287  0.780000              0.973000
# 12  1395.148438          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 1   [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 2   [[10  0  0]\n [ 0  7  3]\n [ 0  0 10]]
# 3   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 4   [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 5   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 6   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 7   [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 8   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 9   [[10  0  0]\n [ 0  7  3]\n [ 0  1  9]]
# 10  [[10  0  0]\n [ 0  8  2]\n [ 0  2  8]]
# 11  [[10  0  0]\n [ 0  9  1]\n [ 0  8  2]]
# 12  [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]

# %%
i = -3
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_164626_IRIS.csv
#     train_order                                          algorithm  \
# 0            11  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 1             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 2             1                              SVC(probability=True)
# 3             8                    QuadraticDiscriminantAnalysis()
# 4             0                KNeighborsClassifier(n_neighbors=3)
# 5             5              MLPClassifier(alpha=1, max_iter=1000)
# 6             4  RandomForestClassifier(max_depth=5, max_featur...
# 7             3                DecisionTreeClassifier(max_depth=5)
# 8             7                                       GaussianNB()
# 9            10                               LogisticRegression()
# 10           12  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 11            6                               AdaBoostClassifier()
# 12            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0                   ('petal_length', 'sepal_width')           2   19.825026
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3   21.103687
# 2   ('petal_length', 'sepal_width', 'sepal_length')           3   12.596000
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3   12.853654
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   12.745005
# 5   ('petal_length', 'sepal_width', 'sepal_length')           3   11.147567
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3    6.855767
# 7   ('petal_length', 'sepal_width', 'sepal_length')           3   12.866340
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3   12.930374
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   12.565761
# 10                                ('sepal_length',)           1   17.212741
# 11  ('petal_length', 'sepal_width', 'sepal_length')           3    7.322894
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3    7.769904
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1395.289062     0.959933  0.960000              0.981333
# 1   1384.515625     0.953250  0.953333              0.983000
# 2   1378.601562     0.946465  0.946667              0.995667
# 3   1385.058594     0.939439  0.940000              0.995333
# 4   1378.730469     0.919933  0.920000              0.978667
# 5   1385.003906     0.919187  0.926667              0.987000
# 6   1384.496094     0.918687  0.926667              0.976000
# 7   1384.355469     0.905752  0.913333              0.939333
# 8   1384.980469     0.891442  0.893333              0.975333
# 9   1394.234375     0.850439  0.853333              0.956333
# 10  1395.417969     0.693757  0.700000              0.867333
# 11  1384.929688     0.668476  0.733333              0.971000
# 12  1394.636719          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 1   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 2   [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 3   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 4   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 5   [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 6   [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 7   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 8   [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 9   [[10  0  0]\n [ 0  8  2]\n [ 0  2  8]]
# 10  [[10  0  0]\n [ 3  2  5]\n [ 1  1  8]]
# 11  [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 12  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]

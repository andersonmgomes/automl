# %%
#analysing the results
DS_NAME = 'IRIS'

import os
root_path = os.path.abspath('') #current directory
print('Listing the result files list...')
results_file_list = [f for f in os.listdir(root_path) if ((f[-4:] == '.csv') and (f.find(DS_NAME)>-1))]
results_file_list
# Out:
# Listing the result files list...
# ['20211205_103729_IRIS.csv',
#  '20211205_104915_IRIS.csv',
#  '20211205_105918_IRIS.csv',
#  '20211205_111315_IRIS.csv',
#  '20211205_152759_IRIS_V-SEEDING-POP.csv',
#  '20211205_153821_IRIS_V-SEEDING-POP.csv',
#  '20211205_154931_IRIS_V-SEEDING-POP.csv',
#  '20211205_155901_IRIS_V-SEEDING-POP.csv',
#  '20211205_160528_IRIS_V-SEEDING-POP.csv',
#  '20211205_162543_IRIS_V-SEEDING-POP.csv',
#  '20211205_163219_IRIS_NGEN100.csv',
#  '20211205_164626_IRIS.csv',
#  '20211205_165657_IRIS_CROSSOVER8.csv',
#  '20211205_170441_IRIS_MUT3.csv',
#  '20211205_174641_IRIS_MUT3.csv',
#  '20211205_180246_IRIS_MUT3.csv']

# %%
#loading the dataframe list
import pandas as pd
result_list = [(file_name, pd.read_csv(file_name)) for file_name in results_file_list]
print(len(result_list), 'resuts loaded.')
# Out:
# 16 resuts loaded.

# %%
import numpy as np
main_metric_list = []
for result in result_list:
    main_metric_list.append(result[1].iloc[0,6])
print('média:', np.mean(main_metric_list))
print('max:', np.max(main_metric_list))
# Out:
# média: 0.9548292935508577
# max: 0.9666165413533834

# %%
i = -1 #newest
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_180246_IRIS_MUT3.csv
#     train_order                                          algorithm  \
# 0            11  RandomForestClassifier(max_depth=5, max_featur...
# 1             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 2            19  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 3             1                              SVC(probability=True)
# 4            15  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 5            14                KNeighborsClassifier(n_neighbors=3)
# 6            16                              SVC(probability=True)
# 7            12  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 8             3                DecisionTreeClassifier(max_depth=5)
# 9             4  RandomForestClassifier(max_depth=5, max_featur...
# 10           18                KNeighborsClassifier(n_neighbors=3)
# 11           17                DecisionTreeClassifier(max_depth=5)
# 12            8                    QuadraticDiscriminantAnalysis()
# 13            0                KNeighborsClassifier(n_neighbors=3)
# 14           13  RandomForestClassifier(max_depth=5, max_featur...
# 15            5              MLPClassifier(alpha=1, max_iter=1000)
# 16            7                                       GaussianNB()
# 17           10                               LogisticRegression()
# 18           20  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 19            6                               AdaBoostClassifier()
# 20            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0                                 ('petal_length',)           1   12.786632
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3   20.555725
# 2                                 ('petal_length',)           1   21.595348
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3   12.671368
# 4                   ('petal_length', 'sepal_width')           2   19.835701
# 5                                 ('petal_length',)           1   12.415495
# 6                   ('petal_length', 'sepal_width')           2   12.440018
# 7                  ('petal_length', 'sepal_length')           2   21.061102
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3   12.479176
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   12.761798
# 10                  ('petal_length', 'sepal_width')           2   12.437932
# 11                  ('petal_length', 'sepal_width')           2   12.451951
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3   12.571143
# 13  ('petal_length', 'sepal_width', 'sepal_length')           3   12.507016
# 14                  ('petal_length', 'sepal_width')           2    6.501959
# 15  ('petal_length', 'sepal_width', 'sepal_length')           3   11.359094
# 16  ('petal_length', 'sepal_width', 'sepal_length')           3   12.557135
# 17  ('petal_length', 'sepal_width', 'sepal_length')           3   12.566035
# 18                  ('sepal_width', 'sepal_length')           2   20.582216
# 19  ('petal_length', 'sepal_width', 'sepal_length')           3    7.597663
# 20  ('petal_length', 'sepal_width', 'sepal_length')           3    7.485588
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1395.289062     0.953317  0.946667              0.986000
# 1   1385.507812     0.953317  0.953333              0.988667
# 2   1397.308594     0.953317  0.953333              0.983500
# 3   1379.761719     0.953283  0.953333              0.993333
# 4   1396.867188     0.953283  0.953333              0.986667
# 5   1396.714844     0.946600  0.946667              0.980667
# 6   1397.621094     0.946600  0.946667              0.994000
# 7   1396.863281     0.946600  0.946667              0.989000
# 8   1385.472656     0.946566  0.946667              0.958667
# 9   1385.640625     0.946364  0.960000              0.979333
# 10  1397.261719     0.939916  0.940000              0.974000
# 11  1397.441406     0.933233  0.933333              0.971000
# 12  1386.546875     0.932964  0.933333              0.991333
# 13  1379.546875     0.926550  0.926667              0.979667
# 14  1396.445312     0.926098  0.946667              0.982000
# 15  1386.113281     0.919900  0.926667              0.986000
# 16  1386.460938     0.878816  0.880000              0.976667
# 17  1396.207031     0.851568  0.853333              0.958000
# 18  1397.554688     0.763052  0.766667              0.917333
# 19  1386.562500     0.737633  0.780000              0.961000
# 20  1395.410156          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 1   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 2   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 3   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 4   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 6   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 8   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 9   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 10  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 11  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 12  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 13  [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 14  [[10  0  0]\n [ 0 10  0]\n [ 0  4  6]]
# 15  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 16  [[10  0  0]\n [ 0  9  1]\n [ 0  3  7]]
# 17  [[10  0  0]\n [ 0  9  1]\n [ 0  3  7]]
# 18  [[10  0  0]\n [ 0  8  2]\n [ 0  4  6]]
# 19  [[10  0  0]\n [ 0 10  0]\n [ 0 10  0]]
# 20  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]

# %%
i = -2
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_174641_IRIS_MUT3.csv
#     train_order                                          algorithm  \
# 0            16                    QuadraticDiscriminantAnalysis()
# 1            14                    QuadraticDiscriminantAnalysis()
# 2             8                    QuadraticDiscriminantAnalysis()
# 3            13                    QuadraticDiscriminantAnalysis()
# 4             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 5            11                              SVC(probability=True)
# 6             0                KNeighborsClassifier(n_neighbors=3)
# 7             1                              SVC(probability=True)
# 8            18                KNeighborsClassifier(n_neighbors=3)
# 9             5              MLPClassifier(alpha=1, max_iter=1000)
# 10            4  RandomForestClassifier(max_depth=5, max_featur...
# 11            3                DecisionTreeClassifier(max_depth=5)
# 12            7                                       GaussianNB()
# 13           17                               LogisticRegression()
# 14           10                               LogisticRegression()
# 15           12                    QuadraticDiscriminantAnalysis()
# 16            6                               AdaBoostClassifier()
# 17           15                KNeighborsClassifier(n_neighbors=3)
# 18            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0                   ('petal_length', 'sepal_width')           2   21.274974
# 1                  ('petal_length', 'sepal_length')           2   21.591791
# 2   ('petal_length', 'sepal_width', 'sepal_length')           3   22.153579
# 3                                 ('petal_length',)           1   21.585239
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   40.088965
# 5                  ('petal_length', 'sepal_length')           2   21.315361
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3   26.453958
# 7   ('petal_length', 'sepal_width', 'sepal_length')           3   15.990915
# 8                   ('petal_length', 'sepal_width')           2   25.611770
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   20.180523
# 10  ('petal_length', 'sepal_width', 'sepal_length')           3   11.258254
# 11  ('petal_length', 'sepal_width', 'sepal_length')           3   21.396660
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3   21.602467
# 13                 ('petal_length', 'sepal_length')           2   11.831642
# 14  ('petal_length', 'sepal_width', 'sepal_length')           3   11.075530
# 15                  ('sepal_width', 'sepal_length')           2   21.096835
# 16  ('petal_length', 'sepal_width', 'sepal_length')           3   13.001448
# 17                  ('sepal_width', 'sepal_length')           2   21.954797
# 18  ('petal_length', 'sepal_width', 'sepal_length')           3   11.905728
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1621.070312     0.953047  0.953333              0.994333
# 1   1620.863281     0.953014  0.953333              0.998000
# 2   1610.976562     0.946364  0.946667              0.997333
# 3   1621.003906     0.946123  0.946667              0.994333
# 4   1613.011719     0.946055  0.946667              0.989333
# 5   1621.214844     0.946055  0.946667              0.998000
# 6   1594.039062     0.946022  0.946667              0.985000
# 7   1594.578125     0.945489  0.946667              0.996000
# 8   1620.980469     0.939850  0.940000              0.979333
# 9   1610.628906     0.926482  0.933333              0.990000
# 10  1610.628906     0.919919  0.933333              0.974833
# 11  1610.519531     0.919288  0.920000              0.947667
# 12  1610.718750     0.878509  0.880000              0.983333
# 13  1621.042969     0.849471  0.853333              0.968333
# 14  1620.808594     0.844132  0.846667              0.964667
# 15  1621.292969     0.771770  0.773333              0.921000
# 16  1610.812500     0.751044  0.786667              0.966333
# 17  1621.007812     0.731101  0.733333              0.865167
# 18  1620.808594          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 1   [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]
# 2   [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]
# 3   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 4   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 6   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]
# 8   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 9   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 10  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 11  [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]
# 12  [[10  0  0]\n [ 0  9  1]\n [ 0  3  7]]
# 13  [[10  0  0]\n [ 0  8  2]\n [ 0  1  9]]
# 14  [[10  0  0]\n [ 0  6  4]\n [ 0  2  8]]
# 15  [[10  0  0]\n [ 0  6  4]\n [ 0  4  6]]
# 16  [[10  0  0]\n [ 0 10  0]\n [ 0 10  0]]
# 17  [[10  0  0]\n [ 0  5  5]\n [ 0  1  9]]
# 18  [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]

# %%
i = -3
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_170441_IRIS_MUT3.csv
#     train_order                                          algorithm  \
# 0            11                    QuadraticDiscriminantAnalysis()
# 1             8                    QuadraticDiscriminantAnalysis()
# 2            12                KNeighborsClassifier(n_neighbors=3)
# 3             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 4             3                DecisionTreeClassifier(max_depth=5)
# 5             0                KNeighborsClassifier(n_neighbors=3)
# 6             1                              SVC(probability=True)
# 7            13                              SVC(probability=True)
# 8             4  RandomForestClassifier(max_depth=5, max_featur...
# 9             5              MLPClassifier(alpha=1, max_iter=1000)
# 10            7                                       GaussianNB()
# 11           14                               LogisticRegression()
# 12           10                               LogisticRegression()
# 13            6                               AdaBoostClassifier()
# 14            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0                  ('petal_length', 'sepal_length')           2   15.244949
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3   15.972266
# 2                  ('petal_length', 'sepal_length')           2   15.113519
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3   28.578943
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   15.376448
# 5   ('petal_length', 'sepal_width', 'sepal_length')           3   15.733475
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3   15.621996
# 7                  ('petal_length', 'sepal_length')           2   15.589156
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3    8.249486
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   14.296857
# 10  ('petal_length', 'sepal_width', 'sepal_length')           3   15.009083
# 11                 ('petal_length', 'sepal_length')           2   15.519860
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3   15.414727
# 13  ('petal_length', 'sepal_width', 'sepal_length')           3    8.876419
# 14  ('petal_length', 'sepal_width', 'sepal_length')           3    8.966707
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1396.269531     0.959933  0.960000              0.992667
# 1   1386.765625     0.946600  0.946667              0.990000
# 2   1396.566406     0.946533  0.946667              0.976667
# 3   1385.617188     0.939782  0.940000              0.983000
# 4   1385.656250     0.926516  0.926667              0.944333
# 5   1380.070312     0.919866  0.920000              0.973000
# 6   1380.070312     0.912509  0.913333              0.986000
# 7   1396.039062     0.912509  0.913333              0.987000
# 8   1385.703125     0.912129  0.906667              0.979500
# 9   1386.324219     0.905786  0.893333              0.981667
# 10  1386.175781     0.863560  0.866667              0.975333
# 11  1396.410156     0.842258  0.846667              0.958667
# 12  1396.089844     0.837832  0.840000              0.953000
# 13  1386.312500     0.687696  0.740000              0.973333
# 14  1396.417969          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 1   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 2   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 3   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 4   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 6   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 8   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 9   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 10  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 11  [[10  0  0]\n [ 2  6  2]\n [ 0  0 10]]
# 12  [[10  0  0]\n [ 0  8  2]\n [ 0  1  9]]
# 13  [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 14  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]

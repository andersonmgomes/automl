# %%
#analysing the results
DS_NAME = ''

import os
root_path = os.path.abspath('') #current directory
print('Listing the result files list...')
results_file_list = [f for f in os.listdir(root_path) if ((f[-4:] == '.csv') 
                                                          and ((f.upper().find(DS_NAME.upper())>-1) or (DS_NAME=='')))]
results_file_list
# Out:
# Listing the result files list...
# ['20211205_103729_IRIS.csv',
#  '20211205_104915_IRIS.csv',
#  '20211205_105918_IRIS.csv',
#  '20211205_111315_IRIS.csv',
#  '20211205_152759_IRIS_V-SEEDING-POP.csv',
#  '20211205_153821_IRIS_V-SEEDING-POP.csv',
#  '20211205_154931_IRIS_V-SEEDING-POP.csv',
#  '20211205_155901_IRIS_V-SEEDING-POP.csv',
#  '20211205_160528_IRIS_V-SEEDING-POP.csv',
#  '20211205_162543_IRIS_V-SEEDING-POP.csv',
#  '20211205_163219_IRIS_NGEN100.csv',
#  '20211205_164626_IRIS.csv',
#  '20211205_165657_IRIS_CROSSOVER8.csv',
#  '20211205_170441_IRIS_MUT3.csv',
#  '20211205_174641_IRIS_MUT3.csv',
#  '20211205_180246_IRIS_MUT3.csv',
#  '20211205_205249_HOUSE_CLASS.csv',
#  '20211206_154332.csv',
#  '20211207_061330_IRIS_ENSEMBLE.csv',
#  '20211207_174126_IRIS_ENSEMBLE.csv']

# %%
#loading the dataframe list
import pandas as pd
result_list = [(file_name, pd.read_csv(file_name)) for file_name in results_file_list]
print(len(result_list), 'resuts loaded.')
# Out:
# 20 resuts loaded.

# %%
import numpy as np
main_metric_list = []
for result in result_list:
    main_metric_list.append(result[1].iloc[0,6])
print('média:', np.mean(main_metric_list))
print('max:', np.max(main_metric_list))
# Out:
# média: 0.9341067885372768
# max: 1.0

# %%
i = -1 #newest
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211207_174126_IRIS_ENSEMBLE.csv
#     train_order                                          algorithm  \
# 0             3                           DecisionTreeClassifier()
# 1             9  XGBClassifier(base_score=0.5, booster='gbtree'...
# 2             6                               AdaBoostClassifier()
# 3             4                  RandomForestClassifier(n_jobs=-1)
# 4            14  StackingClassifier(estimators=[('DecisionTreeC...
# 5            18  XGBClassifier(base_score=0.5, booster='gbtree'...
# 6            24                           DecisionTreeClassifier()
# 7            27                       GradientBoostingClassifier()
# 8            13  VotingClassifier(estimators=[('DecisionTreeCla...
# 9             8                    QuadraticDiscriminantAnalysis()
# 10           11                       GradientBoostingClassifier()
# 11           23                              SVC(probability=True)
# 12            0                             KNeighborsClassifier()
# 13           16                               LogisticRegression()
# 14            7                                       GaussianNB()
# 15           15                               LogisticRegression()
# 16            5                                    MLPClassifier()
# 17            2                        GaussianProcessClassifier()
# 18           19                             KNeighborsClassifier()
# 19            1                              SVC(probability=True)
# 20           28                              SVC(probability=True)
# 21           26                                    MLPClassifier()
# 22           25                        GaussianProcessClassifier()
# 23           20                           DecisionTreeClassifier()
# 24           21                           DecisionTreeClassifier()
# 25           22                       GradientBoostingClassifier()
# 26           17  VotingClassifier(estimators=[('DecisionTreeCla...
# 27           10                                    MultinomialNB()
# 28           12                   HistGradientBoostingClassifier()
#
#                                            features  n_features  train_time  \
# 0   ('petal_length', 'sepal_width', 'sepal_length')           3   11.946631
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3    8.298938
# 2   ('petal_length', 'sepal_width', 'sepal_length')           3    7.684903
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3   14.764342
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   32.290610
# 5                  ('petal_length', 'sepal_length')           2    9.449937
# 6                                 ('petal_length',)           1   22.640048
# 7                  ('petal_length', 'sepal_length')           2   10.759516
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3   16.274343
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   14.997042
# 10  ('petal_length', 'sepal_width', 'sepal_length')           3   10.313374
# 11                  ('petal_length', 'sepal_width')           2   15.407452
# 12  ('petal_length', 'sepal_width', 'sepal_length')           3   11.715768
# 13                  ('petal_length', 'sepal_width')           2   15.363061
# 14  ('petal_length', 'sepal_width', 'sepal_length')           3   11.631094
# 15  ('petal_length', 'sepal_width', 'sepal_length')           3   15.295681
# 16  ('petal_length', 'sepal_width', 'sepal_length')           3    7.708196
# 17  ('petal_length', 'sepal_width', 'sepal_length')           3    6.288135
# 18                 ('petal_length', 'sepal_length')           2   15.331441
# 19  ('petal_length', 'sepal_width', 'sepal_length')           3   11.956958
# 20                  ('sepal_width', 'sepal_length')           2   15.830081
# 21                 ('petal_length', 'sepal_length')           2    9.664316
# 22                                ('petal_length',)           1    8.026199
# 23                  ('sepal_width', 'sepal_length')           2   15.428015
# 24                                ('sepal_length',)           1   22.653736
# 25                                ('sepal_length',)           1   10.969391
# 26                  ('sepal_width', 'sepal_length')           2   11.820606
# 27  ('petal_length', 'sepal_width', 'sepal_length')           3   15.357003
# 28  ('petal_length', 'sepal_width', 'sepal_length')           3   10.370027
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1591.558594     1.000000  1.000000              1.000000
# 1   2676.023438     1.000000  1.000000              1.000000
# 2   2664.343750     1.000000  1.000000              1.000000
# 3   2664.214844     1.000000  0.966667              0.991667
# 4   3143.683594     1.000000  1.000000              1.000000
# 5   3230.308594     1.000000  1.000000              1.000000
# 6   3230.089844     1.000000  1.000000              1.000000
# 7   3229.664062     1.000000  1.000000              1.000000
# 8   3106.718750     1.000000  1.000000                   NaN
# 9   2665.238281     0.964444  0.966667              0.983333
# 10  2675.871094     0.911111  0.933333              0.983333
# 11  3230.484375     0.875556  0.900000              0.991667
# 12  1587.359375     0.840000  0.866667              0.950000
# 13  3142.214844     0.817778  0.833333              0.966667
# 14  2664.859375     0.804444  0.833333              1.000000
# 15  3142.941406     0.804444  0.833333              0.966667
# 16  2664.390625     0.804444  0.833333              0.983333
# 17  1591.742188     0.804444  0.833333              0.941667
# 18  3230.328125     0.786667  0.833333              1.000000
# 19  1587.804688     0.782222  0.800000              0.958333
# 20  3230.105469     0.782222  0.800000              0.866667
# 21  3229.984375     0.771111  0.800000              0.991667
# 22  3230.042969     0.746667  0.800000              0.875000
# 23  3230.156250     0.722222  0.733333              0.825000
# 24  3230.511719     0.637778  0.666667              0.754167
# 25  3229.988281     0.637778  0.666667              0.808333
# 26  3230.207031     0.582222  0.600000                   NaN
# 27  2675.480469     0.457778  0.500000              0.816667
# 28  2675.921875     0.166667  0.333333              0.500000
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0  9  1]\n [ 0  4  6]]
# 1   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 2   [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 3   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 4   [[10  0  0]\n [ 0  9  1]\n [ 0  4  6]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 6   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 8   [[10  0  0]\n [ 0  8  2]\n [ 0  1  9]]
# 9   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 10  [[10  0  0]\n [ 0  8  2]\n [ 0  4  6]]
# 11  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 12  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 13  [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 14  [[10  0  0]\n [ 0  8  2]\n [ 0  2  8]]
# 15  [[10  0  0]\n [ 0  7  3]\n [ 0  2  8]]
# 16  [[10  0  0]\n [ 0  7  3]\n [ 0  2  8]]
# 17  [[10  0  0]\n [ 0  7  3]\n [ 0  2  8]]
# 18  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 19  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 20           [[9 1 0]\n [0 7 3]\n [0 2 8]]
# 21  [[10  0  0]\n [ 2  5  3]\n [ 0  2  8]]
# 22  [[10  0  0]\n [ 2  5  3]\n [ 0  0 10]]
# 23           [[9 0 1]\n [0 7 3]\n [0 5 5]]
# 24  [[10  0  0]\n [ 2  5  3]\n [ 0  2  8]]
# 25  [[10  0  0]\n [ 2  5  3]\n [ 0  2  8]]
# 26           [[9 1 0]\n [0 7 3]\n [0 6 4]]
# 27  [[10  0  0]\n [ 0  4  6]\n [ 0  5  5]]
# 28  [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]

# %%
df = result_list[i][1]
#getting the best result group by algorithm
df_grouped = df.groupby(['algorithm']).max('f1').sort_values(by='f1', ascending=False)
df_grouped
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4236/1198573568.py in <module>
#       1 df = result_list[i][1]
#       2 #getting the best result group by algorithm
# ----> 3 df_grouped = df.groupby(['algorithm']).max('f1').sort_values(by='f1', ascending=False)
#       4 df_grouped
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'f1'

# %%
df_grouped.index[:3]
# Out:
# Index(['GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1))',
#        'QuadraticDiscriminantAnalysis()', 'AdaBoostClassifier()'],
#       dtype='object', name='algorithm')

# %%
result_list[i][1].sort_values(by=['roc_auc'], ascending=False)
# Out:
#     train_order                                          algorithm  \
# 0             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 2            11                    QuadraticDiscriminantAnalysis()
# 1             8                    QuadraticDiscriminantAnalysis()
# 4            10                               LogisticRegression()
# 6             5              MLPClassifier(alpha=1, max_iter=1000)
# 10            7                                       GaussianNB()
# 5             1                              SVC(probability=True)
# 3             6                               AdaBoostClassifier()
# 7             9  XGBClassifier(base_score=0.5, booster='gbtree'...
# 11            4  RandomForestClassifier(max_depth=5, max_featur...
# 8             3                DecisionTreeClassifier(max_depth=5)
# 12           13  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 9             0                KNeighborsClassifier(n_neighbors=3)
# 13           12  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 14           14                KNeighborsClassifier(n_neighbors=3)
#
#                                              features  n_features  \
# 0   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 2   ('Avg. Area Number of Rooms', 'Avg. Area House...           3
# 1   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 4   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 6   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 10  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 5   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 3   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 7   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 11  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 8   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 12  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           3
# 9   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 13  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           3
# 14  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           3
#
#      train_time      mem_max        f1  accuracy   roc_auc  \
# 0   2851.430546  3944.734375  0.706142    0.8642  0.924430
# 2     14.573141  1758.609375  0.702370    0.8632  0.924293
# 1     14.502748  1749.390625  0.702942    0.8634  0.924169
# 4      7.911981  1758.652344  0.689174    0.8652  0.924109
# 6     53.469520  1992.261719  0.684505    0.8630  0.923932
# 10    14.491327  1749.050781  0.647902    0.8544  0.916166
# 5     24.857481  1625.386719  0.685570    0.8602  0.915658
# 3     10.208381  1749.503906  0.692462    0.8556  0.913153
# 7     13.548646  1759.453125  0.679818    0.8460  0.900784
# 11     8.161925  1992.031250  0.588091    0.8374  0.894730
# 8     14.984857  1991.496094  0.657679    0.8318  0.877669
# 12  2995.519620  4443.941406  0.577810    0.8206  0.857458
# 9      7.906560  1604.742188  0.651704    0.8358  0.839252
# 13  2354.894827  4078.222656  0.399960    0.7778  0.767875
# 14     8.067114  2247.105469  0.397443    0.7312  0.654273
#
#            confusion_matrix
# 0   [[698  52]\n [ 85 165]]
# 2   [[703  47]\n [ 85 165]]
# 1   [[699  51]\n [ 90 160]]
# 4   [[714  36]\n [103 147]]
# 6   [[713  37]\n [102 148]]
# 10  [[720  30]\n [112 138]]
# 5   [[712  38]\n [104 146]]
# 3   [[693  57]\n [ 83 167]]
# 7   [[688  62]\n [ 88 162]]
# 11  [[724  26]\n [142 108]]
# 8   [[681  69]\n [ 95 155]]
# 12  [[707  43]\n [116 134]]
# 9   [[680  70]\n [ 96 154]]
# 13  [[694  56]\n [180  70]]
# 14  [[636 114]\n [168  82]]

# %%
i = -2
print(result_list[i][0])
result_list[i][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4236/1669614179.py in <module>
#       1 i = -2
# ----> 2 print(result_list[i][0])
#       3 result_list[i][1]
#
# IndexError: list index out of range

# %%
i = -3
print(result_list[i][0])
result_list[i][1]

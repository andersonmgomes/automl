# %%
#analysing the results
DS_NAME = 'IRIS'

import os
root_path = os.path.abspath('') #current directory
print('Listing the result files list...')
results_file_list = [f for f in os.listdir(root_path) if ((f[-4:] == '.csv') and (f.find(DS_NAME)>-1))]
results_file_list
# Out:
# Listing the result files list...
# ['20211205_103729_IRIS.csv',
#  '20211205_104915_IRIS.csv',
#  '20211205_105918_IRIS.csv',
#  '20211205_111315_IRIS.csv',
#  '20211205_152759_IRIS_V-SEEDING-POP.csv']

# %%
#loading the dataframe list
import pandas as pd
result_list = [(file_name, pd.read_csv(file_name)) for file_name in results_file_list]
print(len(result_list), 'resuts loaded.')
# Out:
# 5 resuts loaded.

# %%
import numpy as np
main_metric_list = []
for result in result_list:
    main_metric_list.append(result[1].iloc[0,6])
print('média:', np.mean(main_metric_list))
print('max:', np.max(main_metric_list))
# Out:
# média: 0.9544023229429073
# max: 0.9599331662489556

# %%
i = -1 #newest
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_152759_IRIS_V-SEEDING-POP.csv
#     train_order                                          algorithm  \
# 0             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 1             1                              SVC(probability=True)
# 2            13                               AdaBoostClassifier()
# 3             8                    QuadraticDiscriminantAnalysis()
# 4             3                DecisionTreeClassifier(max_depth=5)
# 5             5              MLPClassifier(alpha=1, max_iter=1000)
# 6             0                KNeighborsClassifier(n_neighbors=3)
# 7             4  RandomForestClassifier(max_depth=5, max_featur...
# 8             7                                       GaussianNB()
# 9            10                               LogisticRegression()
# 10           12  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 11            6                               AdaBoostClassifier()
# 12           11                DecisionTreeClassifier(max_depth=5)
# 13            9  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                            features  n_features  train_time  \
# 0   ('petal_length', 'sepal_width', 'sepal_length')           3   24.432071
# 1   ('petal_length', 'sepal_width', 'sepal_length')           3   17.197297
# 2                                 ('petal_length',)           1   24.094541
# 3   ('petal_length', 'sepal_width', 'sepal_length')           3   29.710399
# 4   ('petal_length', 'sepal_width', 'sepal_length')           3   16.482244
# 5   ('petal_length', 'sepal_width', 'sepal_length')           3   15.159724
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3   17.355633
# 7   ('petal_length', 'sepal_width', 'sepal_length')           3    8.821598
# 8   ('petal_length', 'sepal_width', 'sepal_length')           3   16.630794
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   23.176594
# 10                  ('sepal_width', 'sepal_length')           2   56.566779
# 11  ('petal_length', 'sepal_width', 'sepal_length')           3   10.075277
# 12                  ('sepal_width', 'sepal_length')           2   21.695489
# 13  ('petal_length', 'sepal_width', 'sepal_length')           3   17.714361
#
#         mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0   1611.917969     0.952806  0.953333              0.988333
# 1   1607.554688     0.952705  0.953333              0.992000
# 2   1623.656250     0.939883  0.940000              0.980000
# 3   1613.140625     0.939849  0.940000              0.991333
# 4   1612.304688     0.938603  0.940000              0.953667
# 5   1612.652344     0.919496  0.920000              0.987000
# 6   1607.109375     0.919490  0.920000              0.983667
# 7   1612.398438     0.919232  0.920000              0.981000
# 8   1612.847656     0.886078  0.886667              0.977333
# 9   1624.484375     0.859513  0.860000              0.955000
# 10  1623.703125     0.779585  0.780000              0.919000
# 11  1612.652344     0.741329  0.773333              0.959000
# 12  1620.957031     0.694538  0.706667              0.845000
# 13  1623.859375          NaN       NaN                   NaN
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 1   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 2   [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 3   [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 4   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 6   [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 8   [[10  0  0]\n [ 0  9  1]\n [ 0  2  8]]
# 9   [[10  0  0]\n [ 0  6  4]\n [ 0  0 10]]
# 10  [[10  0  0]\n [ 0  7  3]\n [ 0  2  8]]
# 11  [[10  0  0]\n [ 0 10  0]\n [ 0  8  2]]
# 12           [[9 1 0]\n [0 5 5]\n [0 1 9]]
# 13  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]

# %%
i = -2
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_111315_IRIS.csv
#    train_order                            algorithm  \
# 0            3      QuadraticDiscriminantAnalysis()
# 1            0  KNeighborsClassifier(n_neighbors=3)
# 2            4      QuadraticDiscriminantAnalysis()
# 3            2  KNeighborsClassifier(n_neighbors=3)
# 4            1  DecisionTreeClassifier(max_depth=5)
#
#                            features  n_features  train_time      mem_max  \
# 0   ('petal_length', 'sepal_width')           2   14.935604  1380.578125
# 1   ('petal_length', 'sepal_width')           2   12.526964  1379.867188
# 2                 ('petal_length',)           1   12.593307  1380.726562
# 3  ('petal_length', 'sepal_length')           2   12.577205  1380.023438
# 4   ('petal_length', 'sepal_width')           2   12.650177  1380.054688
#
#    f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0     0.946156  0.946667              0.992667
# 1     0.946055  0.946667              0.973333
# 2     0.946022  0.946667              0.993333
# 3     0.933166  0.933333              0.984333
# 4     0.918889  0.920000              0.965667
#
#                          confusion_matrix
# 0  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 1  [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 2  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 3  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 4  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]

# %%
i = -3
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211205_105918_IRIS.csv
#    train_order                                          algorithm  \
# 0            1                KNeighborsClassifier(n_neighbors=3)
# 1            4                    QuadraticDiscriminantAnalysis()
# 2            5                KNeighborsClassifier(n_neighbors=3)
# 3            2                KNeighborsClassifier(n_neighbors=3)
# 4            3                DecisionTreeClassifier(max_depth=5)
# 5            0  XGBClassifier(base_score=0.5, booster='gbtree'...
#
#                                           features  n_features  train_time  \
# 0                 ('petal_length', 'sepal_length')           2   16.359605
# 1                 ('petal_length', 'sepal_length')           2   16.732441
# 2                                ('petal_length',)           1   16.852694
# 3  ('petal_length', 'sepal_width', 'sepal_length')           3   16.601423
# 4  ('petal_length', 'sepal_width', 'sepal_length')           3   16.447045
# 5                  ('sepal_width', 'sepal_length')           2    9.551481
#
#        mem_max  f1_weighted  accuracy  roc_auc_ovr_weighted  \
# 0  1597.410156     0.959933  0.960000              0.977333
# 1  1597.550781     0.953283  0.953333              0.995333
# 2  1597.941406     0.933065  0.933333              0.967333
# 3  1597.390625     0.926246  0.926667              0.983667
# 4  1597.269531     0.906089  0.920000              0.951333
# 5  1598.382812          NaN       NaN                   NaN
#
#                          confusion_matrix
# 0  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 1  [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]
# 2  [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 3  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 4  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 5  [[10  0  0]\n [ 0  6  4]\n [ 0  3  7]]

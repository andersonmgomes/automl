# %%
#analysing the results
DS_NAME = ''

import os
root_path = os.path.abspath('') #current directory
print('Listing the result files list...')
results_file_list = [f for f in os.listdir(root_path) if ((f[-4:] == '.csv') 
                                                          and ((f.upper().find(DS_NAME.upper())>-1) or (DS_NAME=='')))]
results_file_list
# Out:
# Listing the result files list...
# ['20211205_103729_IRIS.csv',
#  '20211205_104915_IRIS.csv',
#  '20211205_105918_IRIS.csv',
#  '20211205_111315_IRIS.csv',
#  '20211205_152759_IRIS_V-SEEDING-POP.csv',
#  '20211205_153821_IRIS_V-SEEDING-POP.csv',
#  '20211205_154931_IRIS_V-SEEDING-POP.csv',
#  '20211205_155901_IRIS_V-SEEDING-POP.csv',
#  '20211205_160528_IRIS_V-SEEDING-POP.csv',
#  '20211205_162543_IRIS_V-SEEDING-POP.csv',
#  '20211205_163219_IRIS_NGEN100.csv',
#  '20211205_164626_IRIS.csv',
#  '20211205_165657_IRIS_CROSSOVER8.csv',
#  '20211205_170441_IRIS_MUT3.csv',
#  '20211205_174641_IRIS_MUT3.csv',
#  '20211205_180246_IRIS_MUT3.csv',
#  '20211205_205249_HOUSE_CLASS.csv',
#  '20211206_154332.csv',
#  '20211207_061330_IRIS_ENSEMBLE.csv',
#  '20211207_174126_IRIS_ENSEMBLE.csv',
#  '20211208_094137_IRIS_ENSEMBLE.csv',
#  '20211208_095630_IRIS_ENSEMBLE.csv',
#  '20211208_102232_IRIS_ENSEMBLE.csv',
#  '20211208_144637_IRIS_ENSEMBLE.csv',
#  '20211209_174902_IRIS_HIPER.csv']

# %%
#loading the dataframe list
import pandas as pd
result_list = [(file_name, pd.read_csv(file_name)) for file_name in results_file_list]
print(len(result_list), 'resuts loaded.')
# Out:
# 25 resuts loaded.

# %%
import numpy as np
main_metric_list = []
for result in result_list:
    main_metric_list.append(result[1].iloc[0,6])
print('média:', np.mean(main_metric_list))
print('max:', np.max(main_metric_list))
# Out:
# média: 0.9401743197187103
# max: 1.0

# %%
i = -1 #newest
print(result_list[i][0])
result_list[i][1]
# Out:
# 20211209_174902_IRIS_HIPER.csv
#     train_order                                          algorithm  \
# 0             1                              SVC(probability=True)
# 1            36                               AdaBoostClassifier()
# 2            13                      LogisticRegression(n_jobs=-1)
# 3            21  XGBClassifier(base_score=None, booster=None, c...
# 4            26  StackingClassifier(estimators=[('e1', SVC(prob...
# 5            31                  RandomForestClassifier(n_jobs=-1)
# 6             9  XGBClassifier(base_score=None, booster=None, c...
# 7            24                   HistGradientBoostingClassifier()
# 8            20                               AdaBoostClassifier()
# 9             6                               AdaBoostClassifier()
# 10           14  VotingClassifier(estimators=[('e1', SVC(probab...
# 11            4                  RandomForestClassifier(n_jobs=-1)
# 12           18                      LogisticRegression(n_jobs=-1)
# 13           33                   HistGradientBoostingClassifier()
# 14           29                   HistGradientBoostingClassifier()
# 15           19  StackingClassifier(estimators=[('e1', SVC(prob...
# 16           17  VotingClassifier(estimators=[('e1', SVC(probab...
# 17           34  VotingClassifier(estimators=[('e1', SVC(probab...
# 18           15  StackingClassifier(estimators=[('e1', SVC(prob...
# 19           35                  RandomForestClassifier(n_jobs=-1)
# 20           22                  RandomForestClassifier(n_jobs=-1)
# 21           12                   HistGradientBoostingClassifier()
# 22           30                      LogisticRegression(n_jobs=-1)
# 23            0                             KNeighborsClassifier()
# 24            8                    QuadraticDiscriminantAnalysis()
# 25           28                                       GaussianNB()
# 26            7                                       GaussianNB()
# 27           11                       GradientBoostingClassifier()
# 28            5                     MLPClassifier(warm_start=True)
# 29            3                           DecisionTreeClassifier()
# 30            2                        GaussianProcessClassifier()
# 31           25                      LogisticRegression(n_jobs=-1)
# 32           16                      LogisticRegression(n_jobs=-1)
# 33           32                   HistGradientBoostingClassifier()
# 34           10                                    MultinomialNB()
# 35           27                  RandomForestClassifier(n_jobs=-1)
# 36           23                   HistGradientBoostingClassifier()
#
#                                            features  n_features  train_time  \
# 0   ('petal_length', 'sepal_width', 'sepal_length')           3   25.665028
# 1                   ('petal_length', 'sepal_width')           2   20.665325
# 2   ('petal_length', 'sepal_width', 'sepal_length')           3   14.400192
# 3                  ('petal_length', 'sepal_length')           2   42.335046
# 4                   ('petal_length', 'sepal_width')           2  124.519396
# 5                   ('petal_length', 'sepal_width')           2   61.666853
# 6   ('petal_length', 'sepal_width', 'sepal_length')           3   46.513393
# 7                   ('petal_length', 'sepal_width')           2   29.890871
# 8                  ('petal_length', 'sepal_length')           2   16.566259
# 9   ('petal_length', 'sepal_width', 'sepal_length')           3   16.149058
# 10  ('petal_length', 'sepal_width', 'sepal_length')           3   20.264115
# 11  ('petal_length', 'sepal_width', 'sepal_length')           3   64.767622
# 12                  ('petal_length', 'sepal_width')           2   17.117995
# 13                                ('petal_length',)           1   28.722851
# 14                 ('petal_length', 'sepal_length')           2   31.455313
# 15                 ('petal_length', 'sepal_length')           2   54.057140
# 16                 ('petal_length', 'sepal_length')           2   21.159022
# 17                  ('petal_length', 'sepal_width')           2   38.282136
# 18  ('petal_length', 'sepal_width', 'sepal_length')           3   52.521301
# 19                                ('petal_length',)           1   78.594841
# 20                 ('petal_length', 'sepal_length')           2   59.793456
# 21  ('petal_length', 'sepal_width', 'sepal_length')           3   32.454673
# 22                 ('petal_length', 'sepal_length')           2   16.849145
# 23  ('petal_length', 'sepal_width', 'sepal_length')           3   25.591337
# 24  ('petal_length', 'sepal_width', 'sepal_length')           3   12.912781
# 25                 ('petal_length', 'sepal_length')           2   12.130664
# 26  ('petal_length', 'sepal_width', 'sepal_length')           3   12.175273
# 27  ('petal_length', 'sepal_width', 'sepal_length')           3   18.892212
# 28  ('petal_length', 'sepal_width', 'sepal_length')           3   20.872909
# 29  ('petal_length', 'sepal_width', 'sepal_length')           3   15.742074
# 30  ('petal_length', 'sepal_width', 'sepal_length')           3   19.328984
# 31                                ('sepal_length',)           1   13.841305
# 32                  ('sepal_width', 'sepal_length')           2   14.653655
# 33                  ('sepal_width', 'sepal_length')           2   30.510182
# 34  ('petal_length', 'sepal_width', 'sepal_length')           3   12.276156
# 35                                 ('sepal_width',)           1   64.020091
# 36                                 ('sepal_width',)           1   28.189688
#
#         mem_max  roc_auc_ovr_weighted  f1_weighted  accuracy  \
# 0   4200.804688              1.000000     0.966583  0.966667
# 1   4566.054688              1.000000     0.966583  0.966667
# 2   4514.531250              1.000000     0.966583  0.966667
# 3   4579.390625              1.000000     1.000000  1.000000
# 4   4549.761719              1.000000     1.000000  1.000000
# 5   4576.542969              1.000000     1.000000  1.000000
# 6   4536.175781              1.000000     1.000000  1.000000
# 7   4550.351562              1.000000     0.966583  0.966667
# 8   4527.339844              1.000000     1.000000  1.000000
# 9   4289.765625              1.000000     0.966583  0.966667
# 10  4518.453125              1.000000     0.966583  0.966667
# 11  4296.554688              1.000000     0.966583  0.966667
# 12  4525.714844              1.000000     1.000000  1.000000
# 13  4559.347656              1.000000     0.966583  0.966667
# 14  4563.898438              1.000000     0.966583  0.966667
# 15  4526.253906              1.000000     1.000000  1.000000
# 16  4525.703125              1.000000     0.966583  0.966667
# 17  4559.343750              1.000000     1.000000  1.000000
# 18  4523.687500              1.000000     0.966583  0.966667
# 19  4579.917969              1.000000     1.000000  1.000000
# 20  4563.585938              1.000000     1.000000  1.000000
# 21  4513.480469              1.000000     0.966583  0.966667
# 22  4563.285156              1.000000     0.966583  0.966667
# 23  4193.859375              0.998333     0.966583  0.966667
# 24  4295.175781              0.993333     0.933333  0.933333
# 25  4565.257812              0.993333     0.932660  0.933333
# 26  4289.242188              0.986667     0.865320  0.866667
# 27  4507.082031              0.983333     0.932660  0.933333
# 28  4290.402344              0.978333     0.780220  0.800000
# 29  4238.468750              0.975000     0.966583  0.966667
# 30  4237.386719              0.955000     0.822222  0.833333
# 31  4551.832031              0.916667     0.670552  0.733333
# 32  4525.910156              0.885000     0.649478  0.700000
# 33  4560.468750              0.838333     0.749978  0.766667
# 34  4507.078125              0.831667     0.797980  0.800000
# 35  4576.593750              0.630000     0.427324  0.433333
# 36  4550.210938              0.616667     0.427324  0.433333
#
#                           confusion_matrix
# 0   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 1   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 2   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 3   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 4   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 5   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 6   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 7   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 8   [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 9   [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 10  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 11  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 12  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 13  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 14  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 15  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 16  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 17  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 18  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 19  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 20  [[10  0  0]\n [ 0 10  0]\n [ 0  0 10]]
# 21  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 22  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 23  [[10  0  0]\n [ 0  9  1]\n [ 0  0 10]]
# 24  [[10  0  0]\n [ 0  9  1]\n [ 0  1  9]]
# 25  [[10  0  0]\n [ 0  8  2]\n [ 0  0 10]]
# 26  [[10  0  0]\n [ 0  7  3]\n [ 0  1  9]]
# 27  [[10  0  0]\n [ 0 10  0]\n [ 0  2  8]]
# 28  [[10  0  0]\n [ 0  4  6]\n [ 0  0 10]]
# 29  [[10  0  0]\n [ 0 10  0]\n [ 0  1  9]]
# 30  [[10  0  0]\n [ 0  5  5]\n [ 0  0 10]]
# 31  [[10  0  0]\n [ 2  2  6]\n [ 0  0 10]]
# 32  [[ 9  1  0]\n [ 1  2  7]\n [ 0  0 10]]
# 33  [[ 9  1  0]\n [ 0  4  6]\n [ 0  0 10]]
# 34  [[10  0  0]\n [ 0  8  2]\n [ 0  4  6]]
# 35           [[6 1 3]\n [3 4 3]\n [4 3 3]]
# 36           [[6 1 3]\n [3 4 3]\n [4 3 3]]

# %%
df = result_list[i][1]
#getting the best result group by algorithm
df_grouped = df.groupby(['algorithm']).max('f1').sort_values(by='f1', ascending=False)
df_grouped
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3100/1198573568.py in <module>
#       1 df = result_list[i][1]
#       2 #getting the best result group by algorithm
# ----> 3 df_grouped = df.groupby(['algorithm']).max('f1').sort_values(by='f1', ascending=False)
#       4 df_grouped
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'f1'

# %%
df_grouped.index[:3]
# Out:
# Index(['GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1))',
#        'QuadraticDiscriminantAnalysis()', 'AdaBoostClassifier()'],
#       dtype='object', name='algorithm')

# %%
result_list[i][1].sort_values(by=['roc_auc'], ascending=False)
# Out:
#     train_order                                          algorithm  \
# 0             2  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 2            11                    QuadraticDiscriminantAnalysis()
# 1             8                    QuadraticDiscriminantAnalysis()
# 4            10                               LogisticRegression()
# 6             5              MLPClassifier(alpha=1, max_iter=1000)
# 10            7                                       GaussianNB()
# 5             1                              SVC(probability=True)
# 3             6                               AdaBoostClassifier()
# 7             9  XGBClassifier(base_score=0.5, booster='gbtree'...
# 11            4  RandomForestClassifier(max_depth=5, max_featur...
# 8             3                DecisionTreeClassifier(max_depth=5)
# 12           13  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 9             0                KNeighborsClassifier(n_neighbors=3)
# 13           12  GaussianProcessClassifier(kernel=1**2 * RBF(le...
# 14           14                KNeighborsClassifier(n_neighbors=3)
#
#                                              features  n_features  \
# 0   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 2   ('Avg. Area Number of Rooms', 'Avg. Area House...           3
# 1   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 4   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 6   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 10  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 5   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 3   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 7   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 11  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 8   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 12  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           3
# 9   ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           4
# 13  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           3
# 14  ('Avg. Area Number of Bedrooms', 'Avg. Area Nu...           3
#
#      train_time      mem_max        f1  accuracy   roc_auc  \
# 0   2851.430546  3944.734375  0.706142    0.8642  0.924430
# 2     14.573141  1758.609375  0.702370    0.8632  0.924293
# 1     14.502748  1749.390625  0.702942    0.8634  0.924169
# 4      7.911981  1758.652344  0.689174    0.8652  0.924109
# 6     53.469520  1992.261719  0.684505    0.8630  0.923932
# 10    14.491327  1749.050781  0.647902    0.8544  0.916166
# 5     24.857481  1625.386719  0.685570    0.8602  0.915658
# 3     10.208381  1749.503906  0.692462    0.8556  0.913153
# 7     13.548646  1759.453125  0.679818    0.8460  0.900784
# 11     8.161925  1992.031250  0.588091    0.8374  0.894730
# 8     14.984857  1991.496094  0.657679    0.8318  0.877669
# 12  2995.519620  4443.941406  0.577810    0.8206  0.857458
# 9      7.906560  1604.742188  0.651704    0.8358  0.839252
# 13  2354.894827  4078.222656  0.399960    0.7778  0.767875
# 14     8.067114  2247.105469  0.397443    0.7312  0.654273
#
#            confusion_matrix
# 0   [[698  52]\n [ 85 165]]
# 2   [[703  47]\n [ 85 165]]
# 1   [[699  51]\n [ 90 160]]
# 4   [[714  36]\n [103 147]]
# 6   [[713  37]\n [102 148]]
# 10  [[720  30]\n [112 138]]
# 5   [[712  38]\n [104 146]]
# 3   [[693  57]\n [ 83 167]]
# 7   [[688  62]\n [ 88 162]]
# 11  [[724  26]\n [142 108]]
# 8   [[681  69]\n [ 95 155]]
# 12  [[707  43]\n [116 134]]
# 9   [[680  70]\n [ 96 154]]
# 13  [[694  56]\n [180  70]]
# 14  [[636 114]\n [168  82]]

# %%
i = -2
print(result_list[i][0])
result_list[i][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4236/1669614179.py in <module>
#       1 i = -2
# ----> 2 print(result_list[i][0])
#       3 result_list[i][1]
#
# IndexError: list index out of range

# %%
i = -3
print(result_list[i][0])
result_list[i][1]
